# %%
import pandas as pd
import pyarrow as pa

# %%
# https://data.world/sportsvizsunday/june-2020-nba-shots-1997-2019
df = pd.read_csv("~/downloads/NBA Shot Locations 1997 - 2020.csv")

# %%
def plen(arr):
	return f"{len(arr):,}"
plen(df) + " shots"
# Out:
# '4,729,512 shots'

# %%
df.sample(10)
# Out:
#           Game ID  Game Event ID  Player ID      Player Name     Team ID  \
# 4221527  21800088            132     203101    Miles Plumlee  1610612737
# 248345   29800552            423        386     Elliot Perry  1610612751
# 1980623  20700198            127       2408       Melvin Ely  1610612740
# 289329   29800004            425        934  Derrick Coleman  1610612766
# 2178089  20801065            205       2216    Zach Randolph  1610612746
# 2731379  21100275            309     201956      Omri Casspi  1610612739
# 3779573  21600408            266     203138  Hollis Thompson  1610612755
# 3875005  21700515            412    1627742   Brandon Ingram  1610612747
# 191568   29800102            273       1073    Reggie Slater  1610612761
# 1385956  20401064            389       2544     LeBron James  1610612739
#
#                     Team Name  Period  Minutes Remaining  Seconds Remaining  \
# 4221527         Atlanta Hawks       1                  3                 37
# ...

# %%
df.sample(10_000).to_parquet("./shots-10k.parquet")
