# %%
import pandas as pd
import pyarrow as pa

# %%
# https://data.world/sportsvizsunday/june-2020-nba-shots-1997-2019
df = pd.read_parquet("./shots.parquet")

# %%
def plen(arr):
	return f"{len(arr):,}"
plen(df) + " shots"
# Out:
# '4,729,512 shots'

# %%
df.sample(10)
# Out:
#           Game ID  Game Event ID  Player ID           Player Name     Team ID  \
# 3891303  21700179            578    1628368          De'Aaron Fox  1610612758
# 3983449  21700829            320     203078          Bradley Beal  1610612764
# 1745214  20601108             25       2052     DeShawn Stevenson  1610612764
# 2096362  20800104            310       1802           Brad Miller  1610612758
# 4204127  21800338             30     202703        Nikola Mirotic  1610612740
# 2182255  20800546             15       2243      Brian Scalabrine  1610612738
# 3264661  21400584             64     201566     Russell Westbrook  1610612760
# 1914907  20700133            392       1921        Gordan Giricek  1610612762
# 4541900  40500124            247     101180  Sarunas Jasikevicius  1610612754
# 540310   20000747            426       1718           Paul Pierce  1610612738
#
#                      Team Name  Period  Minutes Remaining  Seconds Remaining  \
# ...

# %%
trimmed = df[["X Location", "Y Location", "Shot Made Flag", "Player Name", "Season Type", "Game Date", "Shot Distance"]]

# %%
trimmed.to_parquet("shots-trimmed.parquet", index=False)

# %%
df.keys()
# Out:
# Index(['Game ID', 'Game Event ID', 'Player ID', 'Player Name', 'Team ID',
#        'Team Name', 'Period', 'Minutes Remaining', 'Seconds Remaining',
#        'Action Type', 'Shot Type', 'Shot Zone Basic', 'Shot Zone Area',
#        'Shot Zone Range', 'Shot Distance', 'X Location', 'Y Location',
#        'Shot Made Flag', 'Game Date', 'Home Team', 'Away Team', 'Season Type'],
#       dtype='object')
